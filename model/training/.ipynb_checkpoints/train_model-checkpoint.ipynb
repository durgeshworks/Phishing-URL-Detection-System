# %%
import sagemaker
from sagemaker.inputs import TrainingInput
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri

role = get_execution_role()
sess = sagemaker.Session()

# Upload dataset to S3
# s3_train_path = sess.upload_data("phishing_dataset.csv", key_prefix="phishing/train")
s3_train_path = "s3://amzn-purlds-demo/data/processed/features.csv"
train_input = TrainingInput(s3_train_path, content_type='text/csv')

model_output_path = "s3://amzn-purlds-demo/model/output"

# Use SageMaker’s built-in XGBoost container
container = sagemaker.image_uris.retrieve("xgboost", sess.boto_region_name, "1.5-1")

xgb = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    output_path=model_output_path,
    sagemaker_session=sess
)

xgb.set_hyperparameters(objective="binary:logistic", num_round=100)
xgb.fit({"train": train_input})
#xgb.fit(train_input)

# Deploy model
predictor = xgb.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-10-24-16-14-15-887
# 2025-10-24 16:14:19 Starting - Starting the training job...
# 2025-10-24 16:14:34 Starting - Preparing the instances for training...
# 2025-10-24 16:15:00 Downloading - Downloading input data...
# 2025-10-24 16:15:31 Downloading - Downloading the training image......
# 2025-10-24 16:16:27 Training - Training image download completed. Training in progress./miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-10-24 16:16:44.231 ip-10-2-102-111.ec2.internal:8 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-10-24 16:16:44.255 ip-10-2-102-111.ec2.internal:8 INFO profiler_config_parser.py:111] User has disabled profiler.
# ...
